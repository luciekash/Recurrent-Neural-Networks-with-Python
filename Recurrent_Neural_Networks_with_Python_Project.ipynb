# %% [markdown]
# <a href="https://colab.research.google.com/github/luciekash/Recurrent-Neural-Networks-with-Python/blob/main/Recurrent_Neural_Networks_with_Python_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # <font color='#2F4F4F'>AfterWork Data Science: Recurrent Neural Networks with Python - Project</font>

# %% [markdown]
# ## <font color='#2F4F4F'>Step 1. Business Understanding </font>

# %% [markdown]
# ### a) Specifying the Research Question
#
# Build a recurrent neural networks model that will be used to predict Tesla stock prices in 2017 using data from 2012-2016

# %% [markdown]
# ### b) Defining the Metric for Success
#
# Build a neural networks regression model with an RSME  less than 10% of the target mean.

# %% [markdown]
# ### c) Understanding the Context
#
# Stockpy is an innovative fintech enabling financial prosperity for the entire population. It is a venture funded startup based in Palo Alto bringing world-class financial experiences to a continually growing customer base. As Stockpy enters an expansion phase for innovative fintech product offerings, it aims to enhance the enormous value in data processing and analysis for continuous growth and success.
#
# As a Finance Data Scientist for Stockpy, you provide leadership to turn cutting-edge technology into actionable insights; unlocking the power of data that provides value to business decisions and customer service enhancements.

# %% [markdown]
# ### d) Recording the Experimental Design
#
# * Business Understanding
# * Data Exploration
# * Data Preparation
# * Data Modeling and Evaluation
# * Summary of Findings and Recommendation
# * Challenging the Solution

# %% [markdown]
# ## <font color='#2F4F4F'>Step 2. Data Importation</font>

# %%
# Importing standard libraries
# ---
# 
import pandas as pd
import numpy as np

# %%
# Importing our dataset
# ---
#
df_train = pd.read_csv('https://bit.ly/38dSbSb')
df_train
# Out:
#             Date       Open       High        Low      Close  Adj Close  \
# 0     2012-01-03   5.788000   5.900000   5.530000   5.616000   5.616000
# 1     2012-01-04   5.642000   5.734000   5.500000   5.542000   5.542000
# 2     2012-01-05   5.552000   5.586000   5.370000   5.424000   5.424000
# 3     2012-01-06   5.440000   5.558000   5.282000   5.382000   5.382000
# 4     2012-01-09   5.400000   5.498000   5.224000   5.450000   5.450000
# ...          ...        ...        ...        ...        ...        ...
# 1253  2016-12-23  41.599998  42.689999  41.542000  42.667999  42.667999
# 1254  2016-12-27  42.976002  44.450001  42.883999  43.905998  43.905998
# 1255  2016-12-28  44.306000  44.759998  43.439999  43.948002  43.948002
# 1256  2016-12-29  43.712002  43.840000  42.824001  42.936001  42.936001
# 1257  2016-12-30  43.259998  43.500000  42.335999  42.737999  42.737999
#
#         Volume
# 0      4640500
# 1      3150500
# 2      5027500
# 3      4931500
# 4      4485000
# ...        ...
# 1253  23352500
# 1254  29578500
# 1255  18912500
# 1256  20225000
# 1257  23213000
#
# [1258 rows x 7 columns]

# %% [markdown]
# ## <font color='#2F4F4F'>Step 3. Data Exploration</font>

# %%
# Sample dataset
# ---
#
df_train.sample(3)
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 823  2015-04-14  41.714001  41.897999  41.099998  41.492001  41.492001
# 216  2012-11-12   6.058000   6.284000   6.032000   6.214000   6.214000
# 490  2013-12-13  29.610001  30.360001  29.464001  29.530001  29.530001
#
#        Volume
# 823  15130000
# 216   2779500
# 490  52959500

# %%
# Statistical summary
# ---
#
df_train.describe()
# Out:
#               Open         High          Low        Close    Adj Close  \
# count  1258.000000  1258.000000  1258.000000  1258.000000  1258.000000
# mean     31.997898    32.558671    31.403696    31.989245    31.989245
# std      16.911515    17.148543    16.649245    16.903500    16.903500
# min       5.324000     5.370000     4.528000     4.558000     4.558000
# 25%       8.403000     8.556000     8.197000     8.379500     8.379500
# 50%      39.411000    40.123998    38.709000    39.427000    39.427000
# 75%      45.214499    45.934999    44.303000    45.076502    45.076502
# max      57.534000    58.284000    56.080002    57.208000    57.208000
#
#              Volume
# count  1.258000e+03
# mean   2.551310e+07
# std    2.259037e+07
# min    1.824500e+06
# 25%    1.059400e+07
# 50%    2.007650e+07
# 75%    3.245150e+07
# max    1.858195e+08

# %% [markdown]
# ## <font color='#2F4F4F'>Step 4. Data Preparation</font>

# %%
# Getting our train dataset
# ---
#
train_set = df_train.iloc[:, 1:2].values
print(train_set)
# Out:
# [[ 5.788   ]
#  [ 5.642   ]
#  [ 5.552   ]
#  ...
#  [44.306   ]
#  [43.712002]
#  [43.259998]]

# %%
# Performing Feature scaling
# ---
#
from sklearn.preprocessing import MinMaxScaler
sc = MinMaxScaler(feature_range = (0,1))
training_set_scaled = sc.fit_transform(train_set)

# %%
# Creating a dataset with 60 timesteps and 1 output
# ---
#
X_train = []
y_train = []
for i in range(60, 1258):
    X_train.append(training_set_scaled [i-60:i, 0])
    y_train.append(training_set_scaled [i, 0])
X_train, y_train = np.array(X_train), np.array(y_train)
X_train, y_train
# Out:
# (array([[0.00888719, 0.00609079, 0.00436698, ..., 0.03436123, 0.04037541,
#          0.04275043],
#         [0.00609079, 0.00436698, 0.0022218 , ..., 0.04037541, 0.04275043,
#          0.04432101],
#         [0.00436698, 0.0022218 , 0.00145566, ..., 0.04275043, 0.04432101,
#          0.04175445],
#         ...,
#         [0.71128134, 0.71434589, 0.71105156, ..., 0.69565219, 0.69480939,
#          0.72116457],
#         [0.71434589, 0.71105156, 0.67358745, ..., 0.69480939, 0.72116457,
#          0.74663857],
#         [0.71105156, 0.67358745, 0.66799466, ..., 0.72116457, 0.74663857,
#          0.73526148]]),
#  array([0.04432101, 0.04175445, 0.04102662, ..., 0.74663857, 0.73526148,
#         0.72660406]))

# %%
# Reshaping 
# ---
#
X_train = np.reshape(X_train, (X_train.shape[0], X_train.shape[1], 1))

# %% [markdown]
# ##  <font color='#2F4F4F'>Step 5. Data Modeling</font>

# %%
# Building the RNN
# import keras

from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

# %%
# Initialising the RNN

regressor = Sequential()

# Adding the first LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = True, input_shape = (X_train.shape[1], 1)))
regressor.add(Dropout(0.2))

# Adding a second LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a third LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = True))
regressor.add(Dropout(0.2))

# Adding a fourth LSTM layer and some Dropout regularisation

regressor.add(LSTM(units = 50, return_sequences = False))
regressor.add(Dropout(0.2))

# Adding the output layer

regressor.add(Dense(units = 1))

# %%
# Compile the RNN 
# ---
#

regressor.compile(optimizer = 'adam', loss = 'mean_squared_error')

# %%
# Fitting the RNN to the training set
# ---
#
regressor.fit(X_train, y_train, epochs = 100, batch_size = 32)
# Out:
# Epoch 1/100
# 38/38 [==============================] - 11s 18ms/step - loss: 0.0417
# Epoch 2/100
# 38/38 [==============================] - 1s 17ms/step - loss: 0.0091
# Epoch 3/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0082
# Epoch 4/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0091
# Epoch 5/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0070
# Epoch 6/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0065
# Epoch 7/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0064
# Epoch 8/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0062
# Epoch 9/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0055
# Epoch 10/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0053
# Epoch 11/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0057
# Epoch 12/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0061
# Epoch 13/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0049
# Epoch 14/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0051
# Epoch 15/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0053
# Epoch 16/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0051
# Epoch 17/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0047
# Epoch 18/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 19/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0048
# Epoch 20/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 21/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0043
# Epoch 22/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0042
# Epoch 23/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0046
# Epoch 24/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0045
# Epoch 25/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0041
# Epoch 26/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0038
# Epoch 27/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 28/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0039
# Epoch 29/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 30/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0034
# Epoch 31/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 32/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 33/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0040
# Epoch 34/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 35/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0037
# Epoch 36/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 37/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 38/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0033
# Epoch 39/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0034
# Epoch 40/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 41/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0031
# Epoch 42/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0035
# Epoch 43/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0032
# Epoch 44/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0028
# Epoch 45/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0030
# Epoch 46/100
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0031
# Epoch 47/100
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0029
# Epoch 48/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0028
# Epoch 49/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0033
# Epoch 50/100
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0027
# Epoch 51/100
# 38/38 [==============================] - 1s 26ms/step - loss: 0.0027
# Epoch 52/100
# 38/38 [==============================] - 1s 27ms/step - loss: 0.0027
# Epoch 53/100
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0028
# Epoch 54/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0027
# Epoch 55/100
# 38/38 [==============================] - 1s 23ms/step - loss: 0.0027
# Epoch 56/100
# 38/38 [==============================] - 1s 22ms/step - loss: 0.0027
# Epoch 57/100
# 38/38 [==============================] - 1s 26ms/step - loss: 0.0025
# Epoch 58/100
# 38/38 [==============================] - 1s 25ms/step - loss: 0.0025
# Epoch 59/100
# 38/38 [==============================] - 1s 24ms/step - loss: 0.0023
# Epoch 60/100
# 38/38 [==============================] - 1s 28ms/step - loss: 0.0024
# Epoch 61/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0027
# Epoch 62/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0024
# Epoch 63/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 64/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0027
# Epoch 65/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 66/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0025
# Epoch 67/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 68/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0024
# Epoch 69/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0023
# Epoch 70/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0025
# Epoch 71/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0024
# Epoch 72/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0022
# Epoch 73/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 74/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0022
# Epoch 75/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 76/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0024
# Epoch 77/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 78/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 79/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 80/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 81/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0021
# Epoch 82/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 83/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 84/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 85/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 86/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 87/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0021
# Epoch 88/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 89/100
# 38/38 [==============================] - 1s 13ms/step - loss: 0.0020
# Epoch 90/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0019
# Epoch 91/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 92/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 93/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0019
# Epoch 94/100
# 38/38 [==============================] - 1s 21ms/step - loss: 0.0019
# Epoch 95/100
# 38/38 [==============================] - 1s 20ms/step - loss: 0.0019
# Epoch 96/100
# 38/38 [==============================] - 1s 16ms/step - loss: 0.0020
# Epoch 97/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0020
# Epoch 98/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0018
# Epoch 99/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0017
# Epoch 100/100
# 38/38 [==============================] - 1s 14ms/step - loss: 0.0018

# %%
# Making predictions: Getting the predicted stock price for 2017
# ---
df_test=pd.read_csv("/content/TSLA.csv")
df_test.head(20)
# Out:
#          Date       Open       High        Low      Close  Adj Close    Volume
# 0    1/3/2017  42.972000  44.066002  42.192001  43.397999  43.397999  29616500
# 1    1/4/2017  42.950001  45.599998  42.862000  45.397999  45.397999  56067500
# 2    1/5/2017  45.284000  45.495998  44.389999  45.349998  45.349998  29558500
# 3    1/6/2017  45.386002  46.062000  45.090000  45.801998  45.801998  27639500
# 4    1/9/2017  45.793999  46.383999  45.599998  46.256001  46.256001  19897500
# 5   1/10/2017  46.400002  46.400002  45.377998  45.973999  45.973999  18300000
# 6   1/11/2017  45.813999  45.995998  45.335999  45.945999  45.945999  18254000
# 7   1/12/2017  45.812000  46.139999  45.116001  45.917999  45.917999  18951000
# 8   1/13/2017  46.000000  47.570000  45.917999  47.549999  47.549999  30465000
# 9   1/17/2017  47.340000  47.992001  46.874001  47.116001  47.116001  23087500
# 10  1/18/2017  47.330002  47.942001  47.116001  47.672001  47.672001  18845000
# 11  1/19/2017  49.450001  49.736000  48.150002  48.751999  48.751999  38661500
# 12  1/20/2017  49.091999  49.200001  48.602001  48.945999  48.945999  21021500
# 13  1/23/2017  49.169998  50.178001  49.099998  49.784000  49.784000  31314500
# 14  1/24/2017  50.000000  50.959999  49.930000  50.922001  50.922001  24827500
# 15  1/25/2017  51.462002  51.692001  50.360001  50.894001  50.894001  25713000
# 16  1/26/2017  50.858002  51.147999  50.150002  50.501999  50.501999  15760500
# 17  1/27/2017  50.276001  50.599998  49.703999  50.590000  50.590000  15831500
# 18  1/30/2017  50.506001  51.057999  49.419998  50.125999  50.125999  19005500
# 19  1/31/2017  49.848000  51.178001  49.540001  50.386002  50.386002  20580500

# %%
real_price = df_test.iloc[:, 1:2].values

# Getting the Predicted Stock Price of 2017

#
dataset = pd.concat((df_train['Open'],
                           df_test['Open']), axis=0)

#
inputs = dataset[len(dataset)-len(df_test)-60:].values

# Reshaping the inputs to have only 1 column
# ---
#
inputs = inputs.reshape(-1, 1)


# Using the scale set by the training set to scale the test inputs
# ---
#
inputs = sc.transform(inputs)

# Then creating the test data structure just as we did for the train dataset
# ---

X_test = []
y_test = []

for i in range(60, len(inputs)):
    X_test.append(inputs[i-60:i, 0])
    y_test.append(inputs[i, 0])

X_test, y_test  = np.array(X_test), np.array(y_test)  
X_test = np.reshape(X_test, (X_test.shape[0], X_test.shape[1], 1))

# Making our Predictions
# ---
#
predicted_price = regressor.predict(X_test)


predicted_price = sc.inverse_transform(predicted_price)
print(predicted_price)
# Out:
# [[43.22709 ]
#  [42.845722]
#  [42.575035]
#  [43.428318]
#  [44.413784]
#  [45.076977]
#  [45.55024 ]
#  [45.470306]
#  [45.250683]
#  [45.20086 ]
#  [45.84392 ]
#  [46.413685]
#  [47.62939 ]
#  [48.223824]
#  [48.302284]
#  [48.60595 ]
#  [49.562923]
#  [49.857956]
#  [49.51462 ]
#  [49.35338 ]
#  [49.045692]
#  [49.27652 ]
#  [49.084145]
#  [49.229477]
#  [49.294003]
#  [49.99931 ]
#  [50.359394]
#  [51.30779 ]
#  [52.185432]
#  [52.54843 ]
#  [53.488758]
#  [54.045998]
#  [53.87881 ]
#  [52.410934]
#  [52.77335 ]
#  [53.956432]
#  [52.714504]
#  [50.669556]
#  [49.22898 ]
#  [48.372875]
#  [49.102142]
#  [49.42735 ]
#  [49.425774]
#  [48.970215]
#  [48.962486]
#  [48.56309 ]
#  [48.305294]
#  [48.09309 ]
#  [47.879555]
#  [47.9104  ]
#  [49.073368]
#  [50.483192]
#  [51.22778 ]
#  [50.953884]
#  [50.864532]
#  [49.771114]
#  [49.533978]
#  [49.77295 ]
#  [50.55711 ]
#  [52.836174]
#  [54.139538]
#  [54.182426]
#  [53.986286]
#  [54.851868]
#  [56.63465 ]
#  [57.984737]
#  [57.515907]
#  [57.251583]
#  [58.80574 ]
#  [60.089355]
#  [59.315952]
#  [57.684128]
#  [58.034634]
#  [58.1039  ]
#  [58.527107]
#  [59.181652]
#  [58.65116 ]
#  [59.264423]
#  [59.27862 ]
#  [59.756294]
#  [59.74701 ]
#  [59.403816]
#  [59.99207 ]
#  [61.517464]
#  [60.886974]
#  [59.141323]
#  [57.515373]
#  [58.950638]
#  [59.64191 ]
#  [61.374657]
#  [61.837914]
#  [61.853836]
#  [60.650826]
#  [60.301918]
#  [60.008293]
#  [59.125755]
#  [60.16884 ]
#  [60.248985]
#  [59.79817 ]
#  [59.046986]
#  [59.440002]
#  [60.518387]
#  [61.996704]
#  [63.8457  ]
#  [64.76534 ]
#  [63.826977]
#  [63.454334]
#  [64.61314 ]
#  [66.925415]
#  [68.2835  ]
#  [69.81786 ]
#  [66.497734]
#  [68.38008 ]
#  [71.12172 ]
#  [69.32593 ]
#  [70.37002 ]
#  [69.74191 ]
#  [70.21372 ]
#  [69.84318 ]
#  [70.59827 ]
#  [71.30259 ]
#  [71.8088  ]
#  [69.57267 ]
#  [68.16694 ]
#  [69.273964]
#  [68.307205]
#  [69.53381 ]
#  [65.45416 ]
#  [61.038258]
#  [60.110794]
#  [60.371185]
#  [61.120945]
#  [63.13846 ]
#  [62.948742]
#  [61.22065 ]
#  [60.961277]
#  [59.885067]
#  [61.313255]
#  [61.687225]
#  [62.036022]
#  [62.147865]
#  [64.41678 ]
#  [63.963673]
#  [64.64415 ]
#  [63.326412]
#  [63.130775]
#  [61.562893]
#  [60.998325]
#  [65.15734 ]
#  [66.22432 ]
#  [67.30296 ]
#  [66.81193 ]
#  [67.14784 ]
#  [67.31394 ]
#  [66.70899 ]
#  [68.24282 ]
#  [68.48304 ]
#  [68.04572 ]
#  [67.731995]
#  [66.43045 ]
#  [65.45534 ]
#  [64.90521 ]
#  [64.722885]
#  [66.92813 ]
#  [67.16336 ]
#  [65.51866 ]
#  [63.976974]
#  [65.54371 ]
#  [66.536575]
#  [66.85913 ]
#  [66.21801 ]
#  [65.38528 ]
#  [64.88775 ]
#  [65.56015 ]
#  [66.15752 ]
#  [68.353065]
#  [67.96769 ]
#  [67.72091 ]
#  [69.43193 ]
#  [70.36637 ]
#  [70.07622 ]
#  [68.78754 ]
#  [69.479416]
#  [68.27033 ]
#  [66.38269 ]
#  [66.359055]
#  [66.49255 ]
#  [64.969925]
#  [65.10478 ]
#  [65.16814 ]
#  [63.993996]
#  [66.12369 ]
#  [66.951805]
#  [66.06024 ]
#  [65.20486 ]
#  [64.75558 ]
#  [66.106155]
#  [66.20227 ]
#  [66.81485 ]
#  [66.205864]
#  [65.70022 ]
#  [66.62901 ]
#  [66.71511 ]
#  [66.22707 ]
#  [65.76117 ]
#  [64.07804 ]
#  [63.7976  ]
#  [62.667873]
#  [61.477512]
#  [61.27213 ]
#  [61.468636]
#  [63.209885]
#  [58.793293]
#  [57.4283  ]
#  [58.25016 ]
#  [58.12639 ]
#  [58.53103 ]
#  [58.16378 ]
#  [57.8734  ]
#  [57.437218]
#  [59.28472 ]
#  [58.73765 ]
#  [59.405247]
#  [61.306366]
#  [60.005768]
#  [59.146523]
#  [59.924282]
#  [60.02202 ]
#  [60.019066]
#  [60.48776 ]
#  [60.764095]
#  [59.56719 ]
#  [58.81123 ]
#  [58.885513]
#  [58.48333 ]
#  [58.118732]
#  [59.600285]
#  [60.442215]
#  [60.357307]
#  [62.37677 ]
#  [64.31626 ]
#  [64.24469 ]
#  [64.12947 ]
#  [64.60735 ]
#  [64.112335]
#  [63.10531 ]
#  [62.77459 ]
#  [62.99667 ]
#  [62.354374]
#  [61.122475]
#  [60.290623]]

# %%
# Visualizing the results
import matplotlib.pyplot as plt 

plt.plot(real_price, color='red', label='Real Google Stock Price')
plt.plot(predicted_price, color='blue',
         label='Predicted Google Stock Price')
plt.title('Google Stock Price Prediction by TDP')
plt.xlabel('Time')
plt.ylabel('Google Stock Price')
plt.legend()
plt.show()

# %%
# Model Evaluation
import math
from sklearn.metrics import mean_squared_error
rmse = math.sqrt(mean_squared_error(real_price, predicted_price))
print(rmse)
print(real_price.mean())
# Out:
# 3.5904818032653467
# 62.859242980079685

# %% [markdown]
# ## <font color='#2F4F4F'>Step 6. Summary of Findings and Recommendation</font>

# %% [markdown]
# Your observation goes here...
#
# * The RMSE value obtained is 3.5 which less than 10% of the target mean (62.85). This means the model is of high performance
#
#
# *  The visualization on real and predicted values shows a similar pattern, indicating a high model accuracy

# %% [markdown]
# ## <font color='#2F4F4F'>Step 7. Challenging our Solution</font>

# %% [markdown]
# a) Did we have the right question?
#
# Yes
#
# b) Did we have the right data?
#
# Yes, the data we had was sufficient in answering the research question
#
# c) What can be done to improve the solution?
#
#
# The model performance can be improved through:
#
#
# *   Training with more data
#
# *   Adding more LSTM layers
#
# *  Increasing the timesteps
#
# *  Adding some other indicators
#
# *  Adding more neurons in the LSTM layers
